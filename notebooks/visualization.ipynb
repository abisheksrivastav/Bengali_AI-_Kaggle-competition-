# %%
import sys
sys.path.append("../src/")
import torch
import matplotlib.pyplot as plt
import numpy as np
from dataset import BengaliDatatestTrain
# %matplotlib inline

# %%
dataset = BengaliDatatestTrain(folds=[0,1],img_height=137,img_width=236,
                               mean=(0.485,0.456,0.406),
                               std = (0.229,0.224,0.225))

# %%
len(dataset)
# Out:
# 80336

# %%
idx=4356
img= dataset[idx]["image"]
print(dataset[idx]["grapheme_root"])
print(dataset[idx]["vowel_diacritic"])
print(dataset[idx]["consonant_diacritic"])
npimg = img.numpy()
plt.imshow(np.transpose(npimg,(1,2,0)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tensor(98)
# tensor(2)
# tensor(0)
